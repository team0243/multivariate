# %% [markdown]
# <a href="https://colab.research.google.com/github/team0243/multivariate/blob/main/Function_Numpy_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Function

# %% [markdown]
# ![unnamed.png](data:image/png;base64,...)

# %%
def function_name(_Input_) :
  do_something with  _input_ to produce  _Output_
  return  _Output_
# Out:
#   File "<ipython-input-30-f13137abb281>", line 2
#     do_something with  _input_ to produce  _Output_
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# function มีส่วนสำคัญทั้งหมด 4 ส่วน
#   ####1.บอก python ว่าเราเขียนฟังก์ชัน ชื่ออะไร def function_name(): (ขาดไม่ได้)
#  ###2.กำหนดตัวแปรที่จะเป็น input (ขาดได้)
#   ###3.ส่วนประมวลผล do_someting with input to get Output (ขาดไม่ได้)
#   ###4. ส่วน output return Output(ขาดได้)

# %%
def print_name(name,surename,ID) :
  st = f'ชื่อ {name} นามสกุล {surename} ID {ID}'
  return st

# %% [markdown]
# การเรียกใช้ฟังก์ชัน

# %%
print_name('เกียรติศักดิ์ ','แสนจันทร์', '623021041-7')
# Out:
# 'ชื่อ 623021041-7 นามสกุล เกียรติศักดิ์  ID แสนจันทร์'

# %%
output_string = print_name('เกียรติศักดิ์ ','แสนจันทร์', '623021041-7')
print(output_string)
# Out:
# ชื่อ 623021041-7 นามสกุล เกียรติศักดิ์  ID แสนจันทร์

# %% [markdown]
# ฟังก์ชันไม่จำเป็นต้องมี Output

# %%
def print_name2(surename,ID,name) :
  st = f'ชื่อ {name} นามสกุล {surename} ID {ID}'
  return st

# %%
print_name2('เกียรติศักดิ์ ','แสนจันทร์', '623021041-7')
# Out:
# 'ชื่อ 623021041-7 นามสกุล เกียรติศักดิ์  ID แสนจันทร์'

# %%
op2= print_name2('เกียรติศักดิ์ ','แสนจันทร์', '623021041-7')

# %%
print(op2)
# Out:
# ชื่อ 623021041-7 นามสกุล เกียรติศักดิ์  ID แสนจันทร์

# %% [markdown]
# ฟังก์ชันไม่จำเป็นต้องมี input

# %%
def Pi() :
    return 3.141592

# %%
#คำนวณพื้นที่วงกลมที่มีขนาดเส้นผ่านศูนย์กลางเท่ากับ 3
Pi()*(1.2*2)
# Out:
# 7.5398208

# %% [markdown]
# #input ของ funtion ใน python มีสองแบบ input ที่จำเป็นต้องใส่ กับ input ที่ไม่จำเป็นต้องใส่ (มีค่า default) เราต้องเรียง input ที่จำเป็นต้องใส่ขึ้นก่อน

# %%
def print_default(name, surname, ID, grade='A+'):
   st= f'ชื่อ  {name} นามสกุล {surname} ID {ID}'
   print(st)
   st2= f'เกรด >>>>> {grade}'
   print(st2)

# %%
print_default('เกียรติศักดิ์','แสนจันทร์','623021041-7')
# Out:
# ชื่อ  เกียรติศักดิ์ นามสกุล แสนจันทร์ ID 623021041-7
# เกรด >>>>> A+

# %%
def print_default(name, surname, ID, grade='F'):
   st= f'ชื่อ  {name} นามสกุล {surname} ID {ID}'
   print(st)
   st2= f'เกรด >>>>> {grade}'
   print(st2)

# %% [markdown]
# เราสามารถเรียก FN โดยใช้ชื่อตัวแปรของ FN ช่วยได้

# %%
print_name2(name='เกียรติศักดิ์ ',surename='แสนจันทร์', ID='623021041-7')
# Out:
# 'ชื่อ เกียรติศักดิ์  นามสกุล แสนจันทร์ ID 623021041-7'

# %% [markdown]
# #การบ้าน HW3

# %% [markdown]
# ให้เขียน function คำนวณจำนวนวินาทีจาก เวลาต่อไปนี้
#
# '14-15-31'
#
# '13-00-01'
#
# '05-49-44'
#
# '00-00-16'
#
# และ print ให้สวยงาม

# %%
def time(t):
  j3=  int (t.split('-')[0])*3600
  k3= int (t.split('-')[1])*60
  n3 = int (t.split('-')[2])
  tt = j3+k3+n3
  print("แปลงเป็นวินาทีได้เท่ากับ",tt," วินาที")

# %%
time('14-15-31')
# Out:
# แปลงเป็นวินาทีได้เท่ากับ 51331  วินาที

# %%
time('13-00-01')
# Out:
# แปลงเป็นวินาทีได้เท่ากับ 46801  วินาที

# %%
time('05-49-44')
# Out:
# แปลงเป็นวินาทีได้เท่ากับ 20984  วินาที

# %%
time('00-00-16')
# Out:
# แปลงเป็นวินาทีได้เท่ากับ 16  วินาที

# %% [markdown]
# END

# %% [markdown]
# Numpy -> package สำหรับ Array ที่เป็นตัวเลข (Matrix)
#
# Number-Numerical + python
#
# การใช้ package
# 1. import ชื่อ package #เรียกใช้ package
# 2. ชื่อ package. ชื่อฟังก์ชัน # เรียกใช้ฟังก์ชัน

# %%
import numpy

# %% [markdown]
# ##Array

# %% [markdown]
# data stucture -> array

# %% [markdown]
# สร้าง array (numpy.array)

# %%
mat_ex1 = numpy.array([[5.2,3.0,4.5],[9.1,0.1,0.3]])
print(mat_ex1)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]

# %%
mat_ex1[0,1]  # คู่ แถว,หลัก
# Out:
# 3.0

# %% [markdown]
# ชี้ค่าใน  numpy

# %% [markdown]
# ถ้าไม่มี num array

# %%
list_ex1 = [[5.2,3.0,4.5],[9.1,0.1,0.3]]
print(list_ex1)
# Out:
# [[5.2, 3.0, 4.5], [9.1, 0.1, 0.3]]

# %%
list_ex1[1][2]
# Out:
# 0.3

# %%
print(list_ex1)
a = list_ex1[1]
print(a)
print(a[1])
# Out:
# [[5.2, 3.0, 4.5], [9.1, 0.1, 0.3]]
# [9.1, 0.1, 0.3]
# 0.1

# %% [markdown]
# Matrix Operations
#
# data 2 แบบ -> matrix(2D array),scalar (ตัวเลขค่าคงที่)

# %%
mat_ex1 = numpy.array([[5.2,3.0,4.5],[9.1,0.1,0.3]])
print(mat_ex1)
mat_ex2 = numpy.array([[2,3.7,5.9],[91,1.5,7.3]])
print(mat_ex2)
# Out:
# [[5.2 3.  4.5]
#  [9.1 0.1 0.3]]
# [[ 2.   3.7  5.9]
#  [91.   1.5  7.3]]

# %% [markdown]
# #บวกกับลบ matrix เอาตัวเลขตำแหน่งเดียวกันมาบวกกัน
# (หน้าตาของ matrix ต้องเหมือนกัน)

# %%
mat_ex3 = mat_ex1 + mat_ex2 
print(mat_ex3)
mat_ex4 = mat_ex1 - mat_ex2 
print(mat_ex4)
# Out:
# [[  7.2   6.7  10.4]
#  [100.1   1.6   7.6]]
# [[  3.2  -0.7  -1.4]
#  [-81.9  -1.4  -7. ]]

# %%
mat_ex0 = numpy.array([[1,2],[3,4]])
print(mat_ex0)
# Out:
# [[1 2]
#  [3 4]]

# %% [markdown]
# การตรวจสอบขนาดของ matrix

# %%
mat_ex3.shape
# Out:
# (2, 3)

# %%
mat_ex3.shape[1] # 0 คือ แถว 1 คือหลัก
# Out:
# 3

# %% [markdown]
# #คูณ matrix
# (หลักของ matrix ตัวข้างหน้า ต้องเท่ากับแถวของ Matrix ตัวข้างหลัง)
#
# dot product((AAA,x)(x,ZZZ)) = (AAA,ZZZ)

# %%
mat_w1 = numpy.array([[1,2,3],[3,2,1]])
mat_w2 = numpy.array([[3,2,1],[1,2,3]])

# %%
print(mat_w1)
# Out:
# [[1 2 3]
#  [3 2 1]]

# %% [markdown]
# #Transpose กลับแถวเป็นหลัก กลับหลักเป็นแถว
# matrix.T (โดยการใส่T)

# %%
mat_ex1.T.shape
# Out:
# (3, 2)

# %%
mat_ex2.shape
# Out:
# (2, 3)

# %%
numpy.dot(mat_ex1,mat_ex2.T)  #(2,3).(3,2)  การคูณเมทริกซ์
# Out:
# array([[ 48.05, 510.55],
#        [ 20.34, 830.44]])

# %% [markdown]
# #HW4 อธิบายการหา Determinant และ Inverse matrix (รูป และ อธิบาย)

# %% [markdown]
#  ***Determinant ***

# %% [markdown]
# ให้ A=[aij]n×n ซึ่งเราจะหา A−1 จากสูตร

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ดังนั้น เราจึงสรุปได้ว่าถ้า

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ดีเทอร์มิแนนต์ของเมทริกซ์ขนาด 2×2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ดีเทอร์มิแนนต์ของเทริกซ์ขนาด 3×3 แบบต่อคอลัมน์

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# สรุป เป็นคำพูดง่ายๆ คือ ผลรวมคูณทแยงลง - ผลรวมคูณทแยงขึ้น

# %% [markdown]
# ***Inverse matrix***

# %% [markdown]
# ถ้า A เป็นเมตริกซ์ที่มีมิติ n x n จะพบว่า
#
#   AIn = InA = A
#
# เราจึงเรียก In ว่าเป็นเอกลักษณ์การคูณของเมตริกซ์ และถ้าสามารถหาเมตริกซ์ B ที่ทำให้
#
#  AB = BA = In
#
#  เราจะเรียก B ว่าเป็น อินเวอร์สการคูณของ A

# %% [markdown]
# การหาอินเวอร์สของเมตริกซ์มิติ 1x1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# การหาอินเวอร์สของเมตริกซ์มิติ 2x2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# การหาอินเวอร์สของเมตริกซ์มิติ 3x3
#
# ในการหาอินเวอร์สของเมตริกซ์ที่มีมิติ   n x  n  (n ≥ 3) โดยทั่วไปมี 2 วิธี
#
# 1. การหาอินเวอร์สโดยใช้เมตริกซ์ผูกผัน(Adjoint Matrix)
#
# 2. การหาอินเวอร์สโดยใช้การดำเนินงานแบบแถว
